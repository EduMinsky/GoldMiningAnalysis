# %%
#Lendo os dataframes
import pandas as pd
from pandas_profiling import ProfileReport
path = 'C:\\Users\\User\\Dropbox (CPI)\\EduardoMinsky\\Dados_Mineracao\\Dados Tabulares\\Dados_Relacionados\\'
#Pegando processos apenas do Pará
mun = pd.read_csv(path+'ProcessoMunicipio.csv')
substancia = pd.read_csv(path+'ProcessoSubstancia.csv')
eventos = pd.read_csv(path+'ProcessoEvento.csv')
processos = pd.read_csv(path+'Processo.csv')
pessoa = pd.read_csv(path+'ProcessoPessoa.csv')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_8348\3590157053.py:3: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   from pandas_profiling import ProfileReport

# %%
#Criando analises para evento 333
#Pegando para ouro
ouro = substancia.query('Substancia.str.contains("OURO")',engine = 'python')
#Pegando eventos 333,1402,513
eventos333 = eventos.query('IDEvento == 333')
#Filtrando os processos ativos:
prceossos_ativos = processos.query('BTAtivo=="S"')
#Relacionando os processos ativos com o df 333
eventos333_ativos = eventos333[eventos333['DSProcesso'].isin(prceossos_ativos['DSProcesso'])]
#Relacionando Ouro com os processos de evento 333
eventos333_ativos_ouro = eventos333_ativos[eventos333_ativos['DSProcesso'].isin(ouro['DSProcesso'])]
#Transformando o campo de data do evento333 em datetime
eventos333_ativos_ouro['Data'] = pd.to_datetime(eventos333_ativos_ouro.DTEvento).dt.year
#Tirando registros duplicados
eventos333_ativos_ouro.drop_duplicates(subset='DSProcesso' ,keep ='last',inplace=True)


#Pegando os estados para esses processo ativos de ouro
mun_ouro_ativo_333 = mun[mun['DSProcesso'].isin(eventos333_ativos_ouro['DSProcesso'])]
#Agrupando os estados por Regiao (Norte, sul, Sudeste,CentroOeste, Nordeste)
sul =['RS','SC','PR']
sudeste = ['SP','MG','RJ','ES']
centrooeste =['MS','MT','GO','DF']
nordeste = ['BA','PI','MA','CE','RN','PB','PE','AL','SE']
norte = ['AC','RO','AM','RR','PA','TO','AP']
mun_ouro_ativo_333['Regiao'] = ['Sul' if x in sul else 'Sudeste' if x in sudeste else 'Centro_Oeste' if x in centrooeste else 'Nordeste' if x in nordeste else 'Norte' if x in norte else 'SemEstado' for x in mun_ouro_ativo_333['UF']]
#Dando Join com o df eventos333_ativos_ouro para plotar o ano com regiao do brasil
join_333_regiao = eventos333_ativos_ouro.merge(mun_ouro_ativo_333,on='DSProcesso',how='inner')
join_333_regiao.drop_duplicates(subset='DSProcesso' ,keep ='last',inplace=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_8348\4211226026.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eventos333_ativos_ouro['Data'] = pd.to_datetime(eventos333_ativos_ouro.DTEvento).dt.year
# C:\Users\User\AppData\Local\Temp\ipykernel_8348\4211226026.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eventos333_ativos_ouro.drop_duplicates(subset='DSProcesso' ,keep ='last',inplace=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_8348\4211226026.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mun_ouro_ativo_333['Regiao'] = ['Sul' if x in sul else 'Sudeste' if x in sudeste else 'Centro_Oeste' if x in centrooeste else 'Nordeste' if x in nordeste else 'Norte' if x in norte else 'SemEstado' for x in mun_ouro_ativo_333['UF']]

# %%
#Criando analises para evento 513
#Pegando para ouro
ouro = substancia.query('Substancia.str.contains("OURO")',engine = 'python')
#Pegando eventos 513
eventos513 = eventos.query('IDEvento == 513')
#Filtrando os processos ativos:
prceossos_ativos = processos.query('BTAtivo=="S"')
#Relacionando os processos ativos com o df 513
eventos513_ativos = eventos513[eventos513['DSProcesso'].isin(prceossos_ativos['DSProcesso'])]
#Relacionando Ouro com os processos de evento 513
eventos513_ativos_ouro = eventos513_ativos[eventos513_ativos['DSProcesso'].isin(ouro['DSProcesso'])]
#Transformando o campo de data do evento513 em datetime
eventos513_ativos_ouro['Data'] = pd.to_datetime(eventos513_ativos_ouro.DTEvento).dt.year
#Tirando registros duplicados
eventos513_ativos_ouro.drop_duplicates(subset='DSProcesso' ,keep ='last',inplace=True)


#Pegando os estados para esses processo ativos de ouro
mun_ouro_ativo_513 = mun[mun['DSProcesso'].isin(eventos513_ativos_ouro['DSProcesso'])]
#Agrupando os estados por Regiao (Norte, sul, Sudeste,CentroOeste, Nordeste)
sul =['RS','SC','PR']
sudeste = ['SP','MG','RJ','ES']
centrooeste =['MS','MT','GO','DF']
nordeste = ['BA','PI','MA','CE','RN','PB','PE','AL','SE']
norte = ['AC','RO','AM','RR','PA','TO','AP']
mun_ouro_ativo_513['Regiao'] = ['Sul' if x in sul else 'Sudeste' if x in sudeste else 'Centro_Oeste' if x in centrooeste else 'Nordeste' if x in nordeste else 'Norte' if x in norte else 'SemEstado' for x in mun_ouro_ativo_513['UF']]
#Dando Join com o df eventos333_ativos_ouro para plotar o ano com regiao do brasil
join_513_regiao = eventos513_ativos_ouro.merge(mun_ouro_ativo_513,on='DSProcesso',how='inner')
join_513_regiao.drop_duplicates(subset='DSProcesso' ,keep ='last',inplace=True)
full_join = join_513_regiao.merge(join_333_regiao,how='inner',on='DSProcesso')
full_join
#Temos agora o dataframe eventos513_ativos_ouro que contem informaçoes para os processos de ouro, com evento 513
#E tambem temos esse mesmo dataframe mas separado por UF e regiões do BRasil
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_8348\2940845996.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eventos513_ativos_ouro['Data'] = pd.to_datetime(eventos513_ativos_ouro.DTEvento).dt.year
# C:\Users\User\AppData\Local\Temp\ipykernel_8348\2940845996.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eventos513_ativos_ouro.drop_duplicates(subset='DSProcesso' ,keep ='last',inplace=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_8348\2940845996.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mun_ouro_ativo_513['Regiao'] = ['Sul' if x in sul else 'Sudeste' if x in sudeste else 'Centro_Oeste' if x in centrooeste else 'Nordeste' if x in nordeste else 'Norte' if x in norte else 'SemEstado' for x in mun_ouro_ativo_513['UF']]
#       Unnamed: 0_x_x    DSProcesso  IDEvento_x  DTEvento_x  \
# 0              71881  650.004/2000         513  2018-04-26
# 1              71924  650.005/2000         513  2018-04-26
# 2              71968  650.006/2000         513  2018-04-26
# 3              72137  650.007/2000         513  2017-06-09
# 4              72184  650.008/2000         513  2018-04-26
# ...              ...           ...         ...         ...
# 2258         8201451  867.530/2021         513  2022-05-04
# 2259         8201484  867.531/2021         513  2022-05-04
# 2260         8201936  867.551/2021         513  2022-09-29
# 2261         8204014  867.660/2021         513  2023-04-06
# 2262         8349073  869.600/1996         513  1999-05-04
#
#                                 Evento__x  Data_x  Unnamed: 0_y_x  \
# 0     PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL    2018            5925
# 1     PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL    2018            5929
# 2     PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL    2018            5933
# 3     PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL    2017            5937
# 4     PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL    2018            5941
# ...                                   ...     ...             ...
# 2258  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL    2022          836212
# 2259  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL    2022          836216
# 2260  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL    2022          836302
# 2261  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL    2023          836767
# 2262  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL    1999          851233
#
#       IDMunicipio_x         Municipios_x UF_x  ... Unnamed: 0_x_y  IDEvento_y  \
# 0           1503606             ITAITUBA   PA  ...          71874         333
# 1           1503606             ITAITUBA   PA  ...          71917         333
# 2           1503606             ITAITUBA   PA  ...          71961         333
# 3           1503606             ITAITUBA   PA  ...          72130         333
# 4           1503606             ITAITUBA   PA  ...          72177         333
# ...             ...                  ...  ...  ...            ...         ...
# 2258        5106505               POCONÉ   MT  ...        8201448         333
# 2259        5106505               POCONÉ   MT  ...        8201481         333
# 2260        5108055  TERRA NOVA DO NORTE   MT  ...        8201933         333
# 2261        5100805              APIACÁS   MT  ...        8204011         333
# 2262        5106505               POCONÉ   MT  ...        8349070         333
#
#       DTEvento_y                                          Evento__y Data_y  \
# 0     2000-03-21  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...   2000
# 1     2000-03-21  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...   2000
# 2     2000-03-21  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...   2000
# 3     2000-03-21  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...   2000
# 4     2000-03-21  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...   2000
# ...          ...                                                ...    ...
# 2258  2021-11-20  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...   2021
# 2259  2021-11-20  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...   2021
# 2260  2021-11-25  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...   2021
# 2261  2021-12-27  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...   2021
# 2262  1996-10-16  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...   1996
#
#       Unnamed: 0_y_y  IDMunicipio_y         Municipios_y UF_y      Regiao_y
# 0               5925        1503606             ITAITUBA   PA         Norte
# 1               5929        1503606             ITAITUBA   PA         Norte
# 2               5933        1503606             ITAITUBA   PA         Norte
# 3               5937        1503606             ITAITUBA   PA         Norte
# 4               5941        1503606             ITAITUBA   PA         Norte
# ...              ...            ...                  ...  ...           ...
# 2258          836212        5106505               POCONÉ   MT  Centro_Oeste
# 2259          836216        5106505               POCONÉ   MT  Centro_Oeste
# 2260          836302        5108055  TERRA NOVA DO NORTE   MT  Centro_Oeste
# 2261          836767        5100805              APIACÁS   MT  Centro_Oeste
# 2262          851233        5106505               POCONÉ   MT  Centro_Oeste
#
# [2263 rows x 21 columns]

# %%
#Criando o DF Final
df_333_513 = join_333_regiao.merge(join_513_regiao,on = 'DSProcesso',how='inner')

# %%
#Quantos processos nós temos?
ativos = processos.query('BTAtivo=="S"').shape[0]
f'Nossa base possui {ativos} registros'
# Out:
# 'Nossa base possui 221512 registros'

# %%
#Desses processos ativos, quantos são de ouro E tiveram seu requerimento de lavra garimpleira protocolizado?
f'Temos {join_333_regiao.shape[0]} processos para ouro e que tiveram seus requerimentos protocolizados. Isso equivale a {(join_333_regiao.shape[0]/ativos)*100} '
# Out:
# 'Temos 17826 processos para ouro e que tiveram seus requerimentos protocolizados. Isso equivale a 8.04741955289104 '

# %%
#Quantos processos tiveram sua permisão de Lavra expedida:
f'Temos {full_join.shape[0]} processos para ouro e que tiveram seus requerimentos protocolizados. Isso equivale a {(full_join.shape[0]/join_333_regiao.shape[0])*100} '
# Out:
# 'Temos 2263 processos para ouro e que tiveram seus requerimentos protocolizados. Isso equivale a 12.694939975316952 '

# %%
join_333_regiao.Data.max()
# Out:
# 2023
